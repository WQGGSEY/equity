# %%
# (예시) train_model.py

import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
DB_DIR = os.environ.get("DIR_PATH")
FEATURE_PATH = f"{DB_DIR}/indicators.parquet"

print("Loading feature map from Parquet...")
# 1400만 행 데이터도 몇 초 안에 로드됩니다.
df = pd.read_parquet(FEATURE_PATH)

print("Load complete.")
print(df.info())
# Out:
# Loading feature map from Parquet...
# Load complete.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14720857 entries, 0 to 14720856
# Data columns (total 24 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ticker         object
#  1   date           object
#  2   open           float64
#  3   high           float64
#  4   low            float64
#  5   close          float64
#  6   volume         int64
#  7   log_return     float64
#  8   rsi_20         float64
#  9   rsi_120        float64
#  10  mfi_14         float64
#  11  b_slope_20     float64
#  12  b_uncert_20    float64
#  13  b_slope_240    float64
#  14  b_uncert_240   float64
#  15  bb_width_20    float64
#  16  bb_width_120   float64
#  17  skewness_20    float64
#  18  skewness_120   float64
#  19  kurtosis_20    float64
#  20  kurtosis_120   float64
#  21  auto_corr_20   float64
#  22  auto_corr_120  float64
#  23  amihud_60      float64
# dtypes: float64(21), int64(1), object(2)
# memory usage: 2.6+ GB
# None
