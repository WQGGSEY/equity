# %%
# (예시) train_model.py

import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
DB_DIR = os.environ.get("DIR_PATH") 
FEATURE_PATH = f"{DB_DIR}/indicators.parquet"

print("Loading feature map from Parquet...")
# 1400만 행 데이터도 몇 초 안에 로드됩니다.
df = pd.read_parquet(FEATURE_PATH)
# Out:
# Loading feature map from Parquet...

# %%
log_reutrn_df_long = df[['ticker', 'date', 'log_return']]
log_return_df_pivot = log_reutrn_df_long.pivot(index='date', columns='ticker', values='log_return')

log_return_df_pivot.columns.tolist()
# Out:
# ['A',
#  'AA',
#  'AAL',
#  'AAMI',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'ABBV',
#  'ABCB',
#  'ABG',
#  'ABM',
#  'ABNB',
#  'ABR',
#  'ABSI',
#  'ABT',
#  'ABUS',
#  'ACA',
#  'ACAD',
#  'ACCO',
#  'ACDC',
#  'ACEL',
#  'ACGL',
#  'ACHC',
#  'ACHR',
#  'ACI',
#  'ACIC',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACRE',
#  'ACT',
#  'ACTG',
#  'ACVA',
#  'ADAM',
#  'ADBE',
#  'ADC',
#  'ADCT',
#  'ADEA',
#  'ADI',
#  'ADM',
#  'ADMA',
#  'ADNT',
#  'ADP',
#  'ADPT',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADUS',
#  'ADV',
#  'AEBI',
#  'AEE',
#  'AEHR',
#  'AEIS',
#  'AEO',
#  'AEP',
#  'AES',
#  'AESI',
#  'AEVA',
#  'AFCG',
#  'AFG',
#  'AFL',
#  'AFRM',
#  'AGCO',
#  'AGIO',
#  'AGL',
#  'AGM',
#  'AGNC',
#  'AGO',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AHH',
#  'AHR',
#  'AI',
#  'AIG',
#  'AIN',
#  'AIOT',
#  'AIP',
#  'AIR',
#  'AIT',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'AKBA',
#  'AKR',
#  'AKRO',
#  'AL',
#  'ALAB',
# ...

# %%
import yfinance as yf
yf.download("^GSPC", period='max', group_by=False)['^GSPC']
# Out:
# /var/folders/rn/q0k246v15yz0vm0xsf9wg9lm0000gn/T/ipykernel_63165/2122455656.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download("^GSPC", period='max', group_by=False)['^GSPC']
# [*********************100%***********************]  1 of 1 completed
# Price              Open         High          Low        Close      Volume
# Date
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2025-10-20  6690.049805  6744.350098  6690.049805  6735.129883  4672170000
# 2025-10-21  6736.750000  6752.160156  6722.029785  6735.350098  5245020000
# ...
